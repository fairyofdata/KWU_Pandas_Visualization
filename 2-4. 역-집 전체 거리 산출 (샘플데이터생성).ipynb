# %%
import pandas as pd

# Sample dataset
data = {
    'Latitude': [37.7749, 34.0522, 40.7128],
    'Longitude': [-122.4194, -118.2437, -74.0060],
    'City': ['San Francisco', 'Los Angeles', 'New York']
}

df = pd.DataFrame(data)

# %%
from math import radians
from haversine import haversine
import pandas as pd

def calculate_distance(lat1, lon1, lat2, lon2):

    lat1_rad = radians(lat1)
    lon1_rad = radians(lon1)
    lat2_rad = radians(lat2)
    lon2_rad = radians(lon2)

    distance = haversine((lat1, lon1), (lat2, lon2))

    return distance

csv_file = df

df = pd.read_csv(csv_file)

latitudes = df['_X']
longitudes = df['_Y']

distances = []

for i in range(len(latitudes)):
    for j in range(i + 1, len(latitudes)):
        lat1 = latitudes[i]
        lon1 = longitudes[i]
        lat2 = latitudes[j]
        lon2 = longitudes[j]

        distance = calculate_distance(lat1, lon1, lat2, lon2)
        distances.append(distance)

for idx, distance in enumerate(distances):
    print(f"거리 {idx+1}: {distance} km")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-83322ecab0fa> in <cell line: 2>()
#       1 from math import radians
# ----> 2 from haversine import haversine
#       3 import pandas as pd
#       4
#       5 def calculate_distance(lat1, lon1, lat2, lon2):
#
# ModuleNotFoundError: No module named 'haversine'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
